# %% [markdown]
# I have moved to the google colaboratory because I was unable to display my map in jupyter lab, after hours of being stuck, even with learning assistants, this was the best solution to be found. thank you to learning assistant brandon and sisu for helping me for a long time :)

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import geoviews as gv
import pyproj
import cartopy

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 0        0            invercargill -46.4000  168.3500     16.18        74
# 1        1                 konarka  19.9000   86.1167     19.22        55
# 2        2                bilibino  68.0546  166.4372    -27.06        99
# 3        3  happy valley-goose bay  53.3168  -60.3315     -1.83        74
# 4        4               jiayuguan  39.8167   98.3000     -5.08        29
#
#    Cloudiness  Wind Speed Country        Date
# 0          98        1.37      NZ  1706411715
# 1          30        2.94      IN  1706411715
# 2         100        2.61      RU  1706411716
# 3          75        4.12      CA  1706411716
# 4           1        1.04      CN  1706411716

# %%
gv.extension('bokeh')
humidity=city_data_df["Humidity"].astype(int)

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    x="Lng",
    y="Lat",
    geo=True,
    tiles="OSM",
    frame_height=700,
    frame_width=900,
    size="Humidity",
    color="City",
    alpha=0.75,
    scale = 1)

# Display the map
map_plot_1
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# Step 2: Narrow down the city_data_df DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_weather_df = city_data_df.loc[(city_data_df["Max Temp"] < 25)
                                    & (city_data_df["Max Temp"] > 20)
                                    & (city_data_df["Humidity"] < 80)
                                    & (city_data_df["Wind Speed"] < 5)
                                    & (city_data_df["Cloudiness"] < 50),:].dropna()

# Drop any rows with null values
# YOUR CODE HERE

# Display sample data
ideal_weather_df
# Out:
#      City_ID                        City      Lat       Lng  Max Temp  \
# 63        63                     toliara -23.3500   43.6667     23.88
# 77        77                         sur  22.5667   59.5289     21.58
# 92        92                     libenge   3.6500   18.6333     21.32
# 124      124                      ovalle -30.5983  -71.2003     22.30
# 222      222                      sokode   8.9833    1.1333     23.84
# 232      232                port lincoln -34.7333  135.8667     22.58
# 254      254                  saint-marc  19.1082  -72.6938     24.54
# 260      260                       kyabe   9.4515   18.9449     20.92
# 302      302  san sebastian de la gomera  28.0916  -17.1133     23.20
# 362      362          san pedro pochutla  15.7333  -96.4667     24.21
# 375      375                   ratnagiri  16.9833   73.3000     24.90
# 405      405                  pedernales  18.0384  -71.7440     24.61
# ...

# %% [markdown]
# Step 3: Create a new DataFrame called hotel_df.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                            City Country      Lat       Lng  Humidity  \
# 63                      toliara      MG -23.3500   43.6667        75
# 77                          sur      OM  22.5667   59.5289        69
# 92                      libenge      CD   3.6500   18.6333        38
# 124                      ovalle      CL -30.5983  -71.2003        67
# 222                      sokode      TG   8.9833    1.1333        31
# 232                port lincoln      AU -34.7333  135.8667        59
# 254                  saint-marc      HT  19.1082  -72.6938        68
# 260                       kyabe      TD   9.4515   18.9449        26
# 302  san sebastian de la gomera      ES  28.0916  -17.1133        16
# 362          san pedro pochutla      MX  15.7333  -96.4667        66
# 375                   ratnagiri      IN  16.9833   73.3000        48
# 405                  pedernales      DO  18.0384  -71.7440        67
# 524                    atakpame      TG   7.5333    1.1333        27
# ...

# %% [markdown]
# Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lon = row["Lng"]

    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    # also learned how to do circle and proximity thanks to learning assistant. 
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()

    #Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# toliara - nearest hotel: Ambary
# sur - nearest hotel: Sur Hotel
# libenge - nearest hotel: Hôtel Wilo et Frères
# ovalle - nearest hotel: Hotel Roxy
# sokode - nearest hotel: No hotel found
# port lincoln - nearest hotel: Boston Hotel
# saint-marc - nearest hotel: Guess House Hotel
# kyabe - nearest hotel: No hotel found
# san sebastian de la gomera - nearest hotel: Hotel Villa Gomera
# san pedro pochutla - nearest hotel: Olimpia
# ratnagiri - nearest hotel: Vihar
# pedernales - nearest hotel: Hostal Doña Chava
# atakpame - nearest hotel: ROCK HOTEL
# santa cruz del sur - nearest hotel: No hotel found
#                            City Country      Lat       Lng  Humidity  \
# 63                      toliara      MG -23.3500   43.6667        75
# 77                          sur      OM  22.5667   59.5289        69
# 92                      libenge      CD   3.6500   18.6333        38
# 124                      ovalle      CL -30.5983  -71.2003        67
# ...

# %% [markdown]
# ```
# Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.
# ```

# %%
gv.extension('bokeh')

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    x="Lng",
    y="Lat",
    geo=True,
    tiles="OSM",
    frame_height=700,
    frame_width=900,
    size="Humidity",
    color="City",
    alpha=0.75,
    scale = 1,
    hover_cols=["Hotel Name", "Country"])

# Display the map
map_plot_2
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
